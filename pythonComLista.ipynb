# %%
import pandas as pd
import plotly.express as px
import pyodbc

# %%
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
dados_x = [ '2017', '2018','2019', '2020']
dados_y = [10,20,25,50]

# %%
display (dados_x)
# Out:
# ['2017', '2018', '2019', '2020']

# %%
display(dados_y)
# Out:
# [10, 20, 25, 50]

# %%
grafico_linha = px.line(x = dados_x, y= dados_y, title = 'Vendas por Ano', line_shape = 'spline')
grafico_linha.show()
