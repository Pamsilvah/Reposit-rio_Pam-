# %%
import pandas as pd
import plotly.express as px
import pyodbc

# %%
dados_produtos =  pd.read_csv('g:\\SQL\\resultados_produtos.csv', delimiter = ";")

# %%
display( pd.read_csv('g:\\SQL\\resultados_produtos.csv', delimiter = ";"))
# Out:
#   SmartWatch   4167800,00
# 0   Notebook  14094500,00
# 1     Tablet   4673600,00
# 2    Android  10822200,00
# 3  Televisão  17342500,00
# 4     Câmera   5890500,00
# 5     iPhone  38101700,00
